# %%
import pandas as pd

# %%
Retail_data = pd.read_csv('C:\\Users\\Admin\\Documents\\ML Project\\Retail_Data_W23.csv')
Retail_data
# Out:
#         Unnamed: 0  Store  DayOfWeek        Date  Customers  Open  Promo  \
# 0           339662    516          5  2014-09-12        665     1      0
# 1           969929    665          2  2013-02-12       1213     1      0
# 2           499245    511          4  2014-04-10        685     1      0
# 3           581706    462          7  2014-01-26          0     0      0
# 4           618037   1113          3  2013-12-25          0     0      0
# ...            ...    ...        ...         ...        ...   ...    ...
# 651008      545188    739          5  2014-02-28        785     1      0
# 651009      393481     25          3  2014-07-16       1476     1      1
# 651010      832852    733          6  2013-06-15       3390     1      0
# 651011      540886    897          2  2014-03-04        330     1      1
# 651012      871124   1095          7  2013-05-12          0     0      0
#
#        StateHoliday  SchoolHoliday        Id
# 0                 0              0   6114289
# ...

# %%
orders = pd.read_csv('C:\\Users\\Admin\\Documents\\ML Project\\Retail_Data_Orders_W23.csv')
orders
# Out:
#         Unnamed: 0        Id  Orders
# 0           339662   6114289    4663
# 1           969929  17459095    6766
# 2           499245   8986783    4422
# 3           581706  10471081       0
# 4           618037  11125039       0
# ...            ...       ...     ...
# 651008      545188   9813757    9850
# 651009      393481   7083031   11401
# 651010      832852  14991709   13377
# 651011      540886   9736321    3420
# 651012      871124  15680605       0
#
# [651013 rows x 3 columns]

# %%
stores = pd.read_csv('C:\\Users\\Admin\\Documents\\ML Project\\Store.csv')
stores
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# ...     ...       ...        ...                  ...
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 1                          11.0                    2007.0       1
# 2                          12.0                    2006.0       1
# ...

# %%
merged_df_outer = pd.merge(Retail_data, stores, on='Store', how='inner')
merged_df_outer
# Out:
#         Unnamed: 0  Store  DayOfWeek        Date  Customers  Open  Promo  \
# 0           339662    516          5  2014-09-12        665     1      0
# 1           969780    516          2  2013-02-12        668     1      0
# 2           497020    516          6  2014-04-12        619     1      0
# 3           546080    516          4  2014-02-27        741     1      0
# 4           557230    516          1  2014-02-17       1021     1      1
# ...            ...    ...        ...         ...        ...   ...    ...
# 651008      481644    750          6  2014-04-26        406     1      0
# 651009      753704    750          7  2013-08-25          0     0      0
# 651010      162424    750          7  2015-03-08          0     0      0
# 651011      851824    750          3  2013-05-29        509     1      1
# 651012      771544    750          5  2013-08-09        362     1      0
#
#        StateHoliday  SchoolHoliday        Id StoreType Assortment  \
# ...

# %%
merged_df_outer.to_csv('C:\\Users\\Admin\\Documents\\ML Project\\merged_output_outer.csv', index=False)

# %%
merged_df_orders = pd.merge(merged_df_outer, orders, on='Id', how='inner')
merged_df_orders
merged_df_orders=merged_df_orders.describe()
merged_df_orders
# Out:
#        Unnamed: 0_x          Store      DayOfWeek      Customers  \
# count  6.510130e+05  651013.000000  651013.000000  651013.000000
# mean   5.085137e+05     558.645629       3.999336     632.851832
# std    2.936636e+05     321.905872       1.998260     464.857658
# min    2.000000e+00       1.000000       1.000000       0.000000
# 25%    2.543520e+05     281.000000       2.000000     404.000000
# 50%    5.084190e+05     558.000000       4.000000     609.000000
# 75%    7.629530e+05     838.000000       6.000000     837.000000
# max    1.017207e+06    1115.000000       7.000000    5458.000000
#
#                 Open          Promo  SchoolHoliday            Id  \
# count  651013.000000  651013.000000  651013.000000  6.510130e+05
# mean        0.829619       0.381558       0.178927  9.153619e+06
# std         0.375967       0.485769       0.383292  5.285944e+06
# min         0.000000       0.000000       0.000000  4.090000e+02
# ...

# %%
merged_df_orders.to_csv('C:\\Users\\Admin\\Documents\\ML Project\\merged_df_orders.csv', index=False)

# %%
stores = pd.read_csv('C:\\Users\\Admin\\Documents\\ML Project\\Store.csv')
stores
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# ...     ...       ...        ...                  ...
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 1                          11.0                    2007.0       1
# 2                          12.0                    2006.0       1
# ...

# %%
Retail_Unlabeled_Data = pd.read_csv('C:\\Users\\Admin\\Documents\\ML Project\\Retail_Unlabeled_Data.csv')
Retail_Unlabeled_Data
# Out:
#         Unnamed: 0  Store  DayOfWeek        Date  Customers  Open  Promo  \
# 0           653370    766          6  2013-11-23        555     1      0
# 1           170341    862          7  2015-03-01          0     0      0
# 2           175575    521          2  2015-02-24        362     1      0
# 3           476125    806          4  2014-05-01          0     0      1
# 4           866193    624          4  2013-05-16        668     1      1
# ...            ...    ...        ...         ...        ...   ...    ...
# 162749       53474   1070          7  2015-06-14          0     0      0
# 162750      583731    257          5  2014-01-24        579     1      1
# 162751      172264    555          5  2015-02-27        399     1      0
# 162752      347299    709          4  2014-09-04       1576     1      1
# 162753      895402    843          6  2013-04-20       1255     1      0
#
#        StateHoliday  SchoolHoliday        Id
# 0                 0              0  11761033
# ...

# %%
merged_unlabelled = pd.merge(Retail_Unlabeled_Data, stores, on='Store', how='inner')
merged_unlabelled
# Out:
#         Unnamed: 0  Store  DayOfWeek        Date  Customers  Open  Promo  \
# 0           653370    766          6  2013-11-23        555     1      0
# 1            56515    766          4  2015-06-11        451     1      0
# 2           508420    766          3  2014-04-02        494     1      1
# 3           828425    766          3  2013-06-19        482     1      1
# 4           123415    766          7  2015-04-12          0     0      0
# ...            ...    ...        ...         ...        ...   ...    ...
# 162749      364646    213          6  2014-08-16        577     1      0
# 162750      268341    213          4  2014-11-27        673     1      1
# 162751      311351    213          7  2014-10-12          0     0      0
# 162752      744247    213          1  2013-09-02        646     1      0
# 162753      620482    213          7  2013-12-22          0     0      0
#
#        StateHoliday  SchoolHoliday        Id StoreType Assortment  \
# ...

# %%
merged_unlabelled.to_csv('C:\\Users\\Admin\\Documents\\ML Project\\merged_unlabelled.csv', index=False)

# %%
merged_df_orders = pd.merge(merged_df_outer, orders, on='Id', how='inner')
merged_df_orders
merged_df_orders.describe(include='all')
# Out:
#         Unnamed: 0_x          Store      DayOfWeek        Date      Customers  \
# count   6.510130e+05  651013.000000  651013.000000      651013  651013.000000
# unique           NaN            NaN            NaN         942            NaN
# top              NaN            NaN            NaN  2013-08-25            NaN
# freq             NaN            NaN            NaN         764            NaN
# mean    5.085137e+05     558.645629       3.999336         NaN     632.851832
# std     2.936636e+05     321.905872       1.998260         NaN     464.857658
# min     2.000000e+00       1.000000       1.000000         NaN       0.000000
# 25%     2.543520e+05     281.000000       2.000000         NaN     404.000000
# 50%     5.084190e+05     558.000000       4.000000         NaN     609.000000
# 75%     7.629530e+05     838.000000       6.000000         NaN     837.000000
# max     1.017207e+06    1115.000000       7.000000         NaN    5458.000000
#
# ...

# %%
merged_df_orders['Store']
# Out:
# 0         516
# 1         516
# 2         516
# 3         516
# 4         516
#          ...
# 651008    750
# 651009    750
# 651010    750
# 651011    750
# 651012    750
# Name: Store, Length: 651013, dtype: int64

# %%
merged_df_orders.isnull()
# Out:
#         Unnamed: 0_x  Store  DayOfWeek   Date  Customers   Open  Promo  \
# 0              False  False      False  False      False  False  False
# 1              False  False      False  False      False  False  False
# 2              False  False      False  False      False  False  False
# 3              False  False      False  False      False  False  False
# 4              False  False      False  False      False  False  False
# ...              ...    ...        ...    ...        ...    ...    ...
# 651008         False  False      False  False      False  False  False
# 651009         False  False      False  False      False  False  False
# 651010         False  False      False  False      False  False  False
# 651011         False  False      False  False      False  False  False
# 651012         False  False      False  False      False  False  False
#
#         StateHoliday  SchoolHoliday     Id  ...  Assortment  \
# ...

# %%
merged_df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651013 entries, 0 to 651012
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Unnamed: 0_x               651013 non-null  int64
#  1   Store                      651013 non-null  int64
#  2   DayOfWeek                  651013 non-null  int64
#  3   Date                       651013 non-null  object
#  4   Customers                  651013 non-null  int64
#  5   Open                       651013 non-null  int64
#  6   Promo                      651013 non-null  int64
#  7   StateHoliday               651013 non-null  object
#  8   SchoolHoliday              651013 non-null  int64
#  9   Id                         651013 non-null  int64
#  10  StoreType                  651013 non-null  object
#  11  Assortment                 651013 non-null  object
#  12  CompetitionDistance        649312 non-null  float64
# ...

# %%
#merged_df_orders=merged_df_orders.drop(columns=['Unnamed: 0_x','Unnamed: 0_y','Id'],inplace=True)

# %%
merged_df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651013 entries, 0 to 651012
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Store                      651013 non-null  int64
#  1   DayOfWeek                  651013 non-null  int64
#  2   Date                       651013 non-null  object
#  3   Customers                  651013 non-null  int64
#  4   Open                       651013 non-null  int64
#  5   Promo                      651013 non-null  int64
#  6   StateHoliday               651013 non-null  object
#  7   SchoolHoliday              651013 non-null  int64
#  8   StoreType                  651013 non-null  object
#  9   Assortment                 651013 non-null  object
#  10  CompetitionDistance        649312 non-null  float64
#  11  CompetitionOpenSinceMonth  443851 non-null  float64
#  12  CompetitionOpenSinceYear   443851 non-null  float64
# ...

# %%
list1=['Store','DayOfWeek','StoreType','Assortment','PromoInterval']

# %%
import seaborn as sns
sns.heatmap(merged_df_orders.isnull(), cbar="crest")
# Out:
# <Axes: >

# %%
set(merged_df_orders['PromoInterval'])
# Out:
# {'Feb,May,Aug,Nov', 'Jan,Apr,Jul,Oct', 'Mar,Jun,Sept,Dec', nan}

# %%
mask=['DayOfWeek','StoreType','Assortment','PromoInterval','Store']
Categorical_group=merged_df_orders[mask]
Categorical_group
# Out:
#         DayOfWeek StoreType Assortment     PromoInterval  Store
# 0               5         a          c  Mar,Jun,Sept,Dec    516
# 1               2         a          c  Mar,Jun,Sept,Dec    516
# 2               6         a          c  Mar,Jun,Sept,Dec    516
# 3               4         a          c  Mar,Jun,Sept,Dec    516
# 4               1         a          c  Mar,Jun,Sept,Dec    516
# ...           ...       ...        ...               ...    ...
# 651008          6         d          a   Jan,Apr,Jul,Oct    750
# 651009          7         d          a   Jan,Apr,Jul,Oct    750
# 651010          7         d          a   Jan,Apr,Jul,Oct    750
# 651011          3         d          a   Jan,Apr,Jul,Oct    750
# 651012          5         d          a   Jan,Apr,Jul,Oct    750
#
# [651013 rows x 5 columns]

# %%
one_hot_encoded_df=pd.get_dummies(merged_df_orders,columns=mask)
#one_hot_encoded_df=pd.get_dummies(merged_df_orders,columns=['Store'])
one_hot_encoded_df.head(5)
# Out:
#          Date  Customers  Open  Promo StateHoliday  SchoolHoliday  \
# 0  2014-09-12        665     1      0            0              0
# 1  2013-02-12        668     1      0            0              0
# 2  2014-04-12        619     1      0            0              0
# 3  2014-02-27        741     1      0            0              0
# 4  2014-02-17       1021     1      1            0              0
#
#    CompetitionDistance  CompetitionOpenSinceMonth  CompetitionOpenSinceYear  \
# 0                 20.0                        NaN                       NaN
# 1                 20.0                        NaN                       NaN
# 2                 20.0                        NaN                       NaN
# 3                 20.0                        NaN                       NaN
# 4                 20.0                        NaN                       NaN
#
#    Promo2  ...  Store_1106  Store_1107  Store_1108  Store_1109  Store_1110  \
# ...

# %%
list(one_hot_encoded_df.columns)
# Out:
# ['DayOfWeek',
#  'Date',
#  'Customers',
#  'Open',
#  'Promo',
#  'StateHoliday',
#  'SchoolHoliday',
#  'StoreType',
#  'Assortment',
#  'CompetitionDistance',
#  'CompetitionOpenSinceMonth',
#  'CompetitionOpenSinceYear',
#  'Promo2',
#  'Promo2SinceWeek',
#  'Promo2SinceYear',
#  'PromoInterval',
#  'Orders',
#  'Store_1',
#  'Store_2',
#  'Store_3',
#  'Store_4',
#  'Store_5',
#  'Store_6',
#  'Store_7',
#  'Store_8',
#  'Store_9',
#  'Store_10',
#  'Store_11',
#  'Store_12',
#  'Store_13',
#  'Store_14',
#  'Store_15',
#  'Store_16',
#  'Store_17',
#  'Store_18',
#  'Store_19',
#  'Store_20',
#  'Store_21',
#  'Store_22',
#  'Store_23',
#  'Store_24',
#  'Store_25',
#  'Store_26',
#  'Store_27',
#  'Store_28',
#  'Store_29',
#  'Store_30',
#  'Store_31',
#  'Store_32',
#  'Store_33',
#  'Store_34',
#  'Store_35',
#  'Store_36',
#  'Store_37',
#  'Store_38',
#  'Store_39',
#  'Store_40',
#  'Store_41',
#  'Store_42',
#  'Store_43',
#  'Store_44',
#  'Store_45',
#  'Store_46',
# ...
